# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("C:\\Users\\Mitali Patil\\Downloads\\data_credit_card_customer_seg.csv")
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10104      0.00000                0.0       0.00              0.00
# 1     C10187      0.00000                0.0      23.00              0.00
# 2     C10680      0.00000                0.0       0.00              0.00
# 3     C10891      0.00000                0.0     199.88              0.00
# 4     C11171      0.00000                0.0      12.65              0.00
# ...      ...          ...                ...        ...               ...
# 8945  C15429  16115.59640                1.0     684.74            105.30
# 8946  C16812  16259.44857                1.0    5024.68           3582.45
# 8947  C15642  16304.88925                1.0    1770.57              0.00
# 8948  C14256  18495.55855                1.0    5288.28           3657.30
# 8949  C10144  19043.13856                1.0   22009.92           9449.07
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df['CREDIT_LIMIT'].value_counts().head()
# Out:
# 3000.0    784
# 1500.0    722
# 1200.0    621
# 1000.0    614
# 2500.0    612
# Name: CREDIT_LIMIT, dtype: int64

# %%
df.round(2)
# Out:
#      CUST_ID   BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10104      0.00                0.0       0.00              0.00
# 1     C10187      0.00                0.0      23.00              0.00
# 2     C10680      0.00                0.0       0.00              0.00
# 3     C10891      0.00                0.0     199.88              0.00
# 4     C11171      0.00                0.0      12.65              0.00
# ...      ...       ...                ...        ...               ...
# 8945  C15429  16115.60                1.0     684.74            105.30
# 8946  C16812  16259.45                1.0    5024.68           3582.45
# 8947  C15642  16304.89                1.0    1770.57              0.00
# 8948  C14256  18495.56                1.0    5288.28           3657.30
# 8949  C10144  19043.14                1.0   22009.92           9449.07
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
print("MEAN: "+str(round(df['CREDIT_LIMIT'].mean(),2)))
df['CREDIT_LIMIT']=df['CREDIT_LIMIT'].fillna(round(df['CREDIT_LIMIT'].mean(),2))
# Out:
# MEAN: 4494.45

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          0
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
print("MEAN: "+str(round(df['MINIMUM_PAYMENTS'].mean(),2)))
df['MINIMUM_PAYMENTS']=df['MINIMUM_PAYMENTS'].fillna(round(df['MINIMUM_PAYMENTS'].mean(),2))
# Out:
# MEAN: 864.21

# %%
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10104      0.00000                0.0       0.00              0.00
# 1     C10187      0.00000                0.0      23.00              0.00
# 2     C10680      0.00000                0.0       0.00              0.00
# 3     C10891      0.00000                0.0     199.88              0.00
# 4     C11171      0.00000                0.0      12.65              0.00
# ...      ...          ...                ...        ...               ...
# 8945  C15429  16115.59640                1.0     684.74            105.30
# 8946  C16812  16259.44857                1.0    5024.68           3582.45
# 8947  C15642  16304.88925                1.0    1770.57              0.00
# 8948  C14256  18495.55855                1.0    5288.28           3657.30
# 8949  C10144  19043.13856                1.0   22009.92           9449.07
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
del df['CUST_ID']

# %%
df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0         0.00000                0.0       0.00              0.00
# 1         0.00000                0.0      23.00              0.00
# 2         0.00000                0.0       0.00              0.00
# 3         0.00000                0.0     199.88              0.00
# 4         0.00000                0.0      12.65              0.00
# ...           ...                ...        ...               ...
# 8945  16115.59640                1.0     684.74            105.30
# 8946  16259.44857                1.0    5024.68           3582.45
# 8947  16304.88925                1.0    1770.57              0.00
# 8948  18495.55855                1.0    5288.28           3657.30
# 8949  19043.13856                1.0   22009.92           9449.07
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                       0.00     89.849004             0.000000
# ...

# %% [markdown]
# ### Create Avg_Purchases

# %%
df['Avg_purchase']=df['PURCHASES']/df['TENURE']

# %%
print(df['Avg_purchase'].head(),'\n ',
df['TENURE'].head(),'\n', df['PURCHASES'].head())
# Out:
# 0     0.000000
# 1     1.916667
# 2     0.000000
# 3    16.656667
# 4     1.054167
# Name: Avg_purchase, dtype: float64
#   0     7
# 1    12
# 2    12
# 3    12
# 4    12
# Name: TENURE, dtype: int64
#  0      0.00
# 1     23.00
# 2      0.00
# 3    199.88
# 4     12.65
# Name: PURCHASES, dtype: float64

# %% [markdown]
# ### Create cash_advance Amount

# %%
df['Avg_cash_advance']=df['CASH_ADVANCE']/df['TENURE']

# %%
print(df['Avg_cash_advance'].head(),'\n ',
df['TENURE'].head(),'\n', df['CASH_ADVANCE'].head())
# Out:
# 0    12.835572
# 1     0.000000
# 2    25.907398
# 3     0.000000
# 4     0.000000
# Name: Avg_cash_advance, dtype: float64
#   0     7
# 1    12
# 2    12
# 3    12
# 4    12
# Name: TENURE, dtype: int64
#  0     89.849004
# 1      0.000000
# 2    310.888779
# 3      0.000000
# 4      0.000000
# Name: CASH_ADVANCE, dtype: float64

# %% [markdown]
#  ### Purchases by type (one-off, installments)

# %%
df.loc[:,['ONEOFF_PURCHASES','INSTALLMENTS_PURCHASES']]
# Out:
#       ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES
# 0                 0.00                    0.00
# 1                 0.00                   23.00
# 2                 0.00                    0.00
# 3                 0.00                  199.88
# 4                 0.00                   12.65
# ...                ...                     ...
# 8945            105.30                  579.44
# 8946           3582.45                 1442.23
# 8947              0.00                 1770.57
# 8948           3657.30                 1630.98
# 8949           9449.07                12560.85
#
# [8950 rows x 2 columns]

# %% [markdown]
# ### Find customers ONEOFF_PURCHASES and INSTALLMENTS_PURCHASES details

# %%
df[(df['ONEOFF_PURCHASES']==0) & (df['INSTALLMENTS_PURCHASES']==0)].shape
# Out:
# (2042, 19)

# %%
df[(df['ONEOFF_PURCHASES']>0) & (df['INSTALLMENTS_PURCHASES']>0)].shape
# Out:
# (2774, 19)

# %%
df[(df['ONEOFF_PURCHASES']>0) & (df['INSTALLMENTS_PURCHASES']==0)].shape
# Out:
# (1874, 19)

# %%
df[(df['ONEOFF_PURCHASES']==0) & (df['INSTALLMENTS_PURCHASES']>0)].shape
# Out:
# (2260, 19)

# %% [markdown]
# ### We found out that there are 4 types of purchase behaviour in the data set. So we need to derive a categorical variable based on their behaviour

# %%
def purchase(df):
    if (df['ONEOFF_PURCHASES']==0) & (df['INSTALLMENTS_PURCHASES']==0):
        return 'none'
    if (df['ONEOFF_PURCHASES']>0) & (df['INSTALLMENTS_PURCHASES']>0):
         return 'both_oneoff_installment'
    if (df['ONEOFF_PURCHASES']>0) & (df['INSTALLMENTS_PURCHASES']==0):
        return 'one_off'
    if (df['ONEOFF_PURCHASES']==0) & (df['INSTALLMENTS_PURCHASES']>0):
        return 'installment'

# %%
df['purchase_type']=df.apply(purchase,axis=1)

# %%
df['purchase_type'].value_counts()
# Out:
# both_oneoff_installment    2774
# installment                2260
# none                       2042
# one_off                    1874
# Name: purchase_type, dtype: int64

# %%
df=pd.concat([df,pd.get_dummies(df['purchase_type'])],axis=1)

# %%
df.head()
# Out:
#    BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0      0.0                0.0       0.00               0.0
# 1      0.0                0.0      23.00               0.0
# 2      0.0                0.0       0.00               0.0
# 3      0.0                0.0     199.88               0.0
# 4      0.0                0.0      12.65               0.0
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    0.00     89.849004             0.000000
# 1                   23.00      0.000000             0.083333
# 2                    0.00    310.888779             0.000000
# 3                  199.88      0.000000             0.750000
# 4                   12.65      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.0                          0.000000
# 1                         0.0                          0.083333
# ...

# %%
df = df.drop(columns=['purchase_type'],axis=1)

# %% [markdown]
# ## Data Normalization

# %%
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
scaler = StandardScaler() 
scaled_df = scaler.fit_transform(df) 

# Normalizing the Data 
normalized_df = normalize(scaled_df) 
  
# Converting the numpy array into a pandas DataFrame 
normalized_df = pd.DataFrame(normalized_df)

# %%
scaled_df.shape
# Out:
# (8950, 23)

# %%
scaled_df
# Out:
# array([[-0.75163981, -3.70327107, -0.46955188, ..., -0.58122082,
#          1.83928189, -0.514625  ],
#        [-0.75163981, -3.70327107, -0.45878669, ...,  1.72051649,
#         -0.54369045, -0.514625  ],
#        [-0.75163981, -3.70327107, -0.46955188, ..., -0.58122082,
#          1.83928189, -0.514625  ],
#        ...,
#        [ 7.08191795,  0.51808382,  0.35916669, ...,  1.72051649,
#         -0.54369045, -0.514625  ],
#        [ 8.13440805,  0.51808382,  2.00563738, ..., -0.58122082,
#         -0.54369045, -0.514625  ],
#        [ 8.39748862,  0.51808382,  9.83223198, ..., -0.58122082,
#         -0.54369045, -0.514625  ]])

# %%
# Select the optimal number of clusters according to "Elbow Method"

scores_1 = []

range_values = range(1, 18)

for i in range_values:
  kmeans = KMeans(n_clusters = i)
  kmeans.fit(scaled_df)
  scores_1.append(kmeans.inertia_) 

plt.plot(scores_1, 'bx-')
plt.title('Deciding the right number of clusters')
plt.xlabel('Clusters')
plt.ylabel('Scores') 
plt.show()

# %% [markdown]
# ### k=4,6,8

# %%
silhouette_scores = []

for n_cluster in range(2, 6):
    silhouette_scores.append( 
        silhouette_score(scaled_df, KMeans(n_clusters = n_cluster).fit_predict(scaled_df))) 
    
# Plotting a bar graph to compare the results 
k = [2, 3, 4, 5] 

plt.bar(k, silhouette_scores) 
plt.xlabel('Number of clusters', fontsize = 10) 
plt.ylabel('Silhouette Score', fontsize = 10) 
plt.show()

# %% [markdown]
# ## k=4

# %%
# Apply K-means algorithms
kmeans = KMeans(4)
kmeans.fit(scaled_df)
labels = kmeans.labels_

# %%
kmeans.cluster_centers_.shape
# Out:
# (4, 23)

# %%
clusters=pd.concat([df, pd.DataFrame({'cluster':labels})], axis=1)
clusters.head()
# Out:
#    BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0      0.0                0.0       0.00               0.0
# 1      0.0                0.0      23.00               0.0
# 2      0.0                0.0       0.00               0.0
# 3      0.0                0.0     199.88               0.0
# 4      0.0                0.0      12.65               0.0
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    0.00     89.849004             0.000000
# 1                   23.00      0.000000             0.083333
# 2                    0.00    310.888779             0.000000
# 3                  199.88      0.000000             0.750000
# 4                   12.65      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.0                          0.000000
# 1                         0.0                          0.083333
# ...

# %%
clusters['cluster'].value_counts()
# Out:
# 0    3534
# 2    3253
# 1    1196
# 3     967
# Name: cluster, dtype: int64

# %%
# Principal component analysis
pca = PCA(n_components=2)
principal = pca.fit_transform(scaled_df)
principal
# Out:
# array([[-2.81634576, -0.63315361],
#        [-1.80162614, -1.89460418],
#        [-2.29801922, -0.376836  ],
#        ...,
#        [ 0.92898594,  7.48170335],
#        [ 6.44474429,  3.9195319 ],
#        [20.00697235,  8.48039451]])

# %%
# Create a new dataframe with the two components
pca_df = pd.DataFrame(data = principal, columns =['pca1','pca2'])
pca_df.head()
# Out:
#        pca1      pca2
# 0 -2.816346 -0.633154
# 1 -1.801626 -1.894604
# 2 -2.298019 -0.376836
# 3 -0.642892 -2.410293
# 4 -1.808402 -1.895706

# %%
# Concatenate the clusters labels to the dataframe
pca_df = pd.concat([pca_df,pd.DataFrame({'cluster':labels})], axis = 1)
pca_df.head()
# Out:
#        pca1      pca2  cluster
# 0 -2.816346 -0.633154        2
# 1 -1.801626 -1.894604        0
# 2 -2.298019 -0.376836        2
# 3 -0.642892 -2.410293        0
# 4 -1.808402 -1.895706        0

# %%
plt.figure(figsize=(10,10))
ax = sns.scatterplot(x="pca1", y="pca2", hue = "cluster", data = pca_df, palette =['red','green','blue','pink'])
plt.show()

# %%
clusters.groupby('cluster').mean()
# Out:
#              BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# cluster
# 0         754.027729           0.853795   667.118362        189.872151
# 1        2272.394333           0.980599  4342.151363       2821.750209
# 2        1250.143431           0.840897   296.402957        294.536397
# 3        4708.185636           0.957630   479.498573        308.548232
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# cluster
# 0                    477.767442    210.937755             0.707400
# 1                   1520.943796    447.392125             0.940724
# 2                      1.906108    732.411794             0.153913
# 3                    171.019576   5271.795121             0.271872
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# cluster
# 0                          0.102645                          0.626770
# 1                          0.691922                          0.728447
# ...

# %%
(clusters[['BALANCE', 'PURCHASES', 'ONEOFF_PURCHASES','INSTALLMENTS_PURCHASES', 'CASH_ADVANCE','CREDIT_LIMIT', 'PAYMENTS','Avg_purchase','Avg_cash_advance', 'cluster']].groupby('cluster').mean().plot.bar(figsize=(15, 5)))
plt.title('Purchase Behavior of various segments')
plt.xlabel('CLUSTERS')
# Out:
# Text(0.5, 0, 'CLUSTERS')

# %% [markdown]
# ## Business Insight
# Cluster 0= These customers mostly take cash advance, and do not use their credit card regularly,They maintain good balance. They must be encouraged to use their card more frequently,as they have higest credit limit.
#
# Cluster 1= These customers are low spenders, despite having a decent credit limit. But maintain very low balance. They usage of credit card is very minimal.They must encourage to transact more.
#
# Cluster 2=These customer have decent credit limit and balance is also decent that means they are we can encourange them to spend more.
#
# Cluster 3= This cluster does the maximum transactions with the credit card, they don’t cross their limit and also make payments to the bank. They take very less cash advance. This is a very good cluster of customers, and they must be given offers and incentives, to retain them.

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
clusters.head()
# Out:
#    BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0      0.0                0.0       0.00               0.0
# 1      0.0                0.0      23.00               0.0
# 2      0.0                0.0       0.00               0.0
# 3      0.0                0.0     199.88               0.0
# 4      0.0                0.0      12.65               0.0
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    0.00     89.849004             0.000000
# 1                   23.00      0.000000             0.083333
# 2                    0.00    310.888779             0.000000
# 3                  199.88      0.000000             0.750000
# 4                   12.65      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.0                          0.000000
# 1                         0.0                          0.083333
# ...

# %%
clusters.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE', 'Avg_purchase', 'Avg_cash_advance', 'both_oneoff_installment',
#        'installment', 'none', 'one_off', 'cluster'],
#       dtype='object')

# %%
# Putting feature variable to X
X = clusters.drop(['BALANCE_FREQUENCY','PURCHASES_FREQUENCY','ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
       'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX','MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
       'TENURE','Avg_purchase','Avg_cash_advance','one_off','both_oneoff_installment','installment','both_oneoff_installment','none','cluster'], axis=1)
X.head()
# Out:
#    BALANCE  PURCHASES  ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  CASH_ADVANCE  \
# 0      0.0       0.00               0.0                    0.00     89.849004
# 1      0.0      23.00               0.0                   23.00      0.000000
# 2      0.0       0.00               0.0                    0.00    310.888779
# 3      0.0     199.88               0.0                  199.88      0.000000
# 4      0.0      12.65               0.0                   12.65      0.000000
#
#    CREDIT_LIMIT    PAYMENTS
# 0        3000.0  138.021428
# 1        5000.0    0.000000
# 2        9000.0    0.000000
# 3        4000.0    0.000000
# 4        5000.0    0.000000

# %%
X.round(2)
# Out:
#        BALANCE  PURCHASES  ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  \
# 0         0.00       0.00              0.00                    0.00
# 1         0.00      23.00              0.00                   23.00
# 2         0.00       0.00              0.00                    0.00
# 3         0.00     199.88              0.00                  199.88
# 4         0.00      12.65              0.00                   12.65
# ...        ...        ...               ...                     ...
# 8945  16115.60     684.74            105.30                  579.44
# 8946  16259.45    5024.68           3582.45                 1442.23
# 8947  16304.89    1770.57              0.00                 1770.57
# 8948  18495.56    5288.28           3657.30                 1630.98
# 8949  19043.14   22009.92           9449.07                12560.85
#
#       CASH_ADVANCE  CREDIT_LIMIT  PAYMENTS
# 0            89.85        3000.0    138.02
# 1             0.00        5000.0      0.00
# ...

# %%
y = clusters['cluster']
y.head()
# Out:
# 0    2
# 1    0
# 2    2
# 3    0
# 4    0
# Name: cluster, dtype: int32

# %%
clusters['cluster'].value_counts()
# Out:
# 0    3534
# 2    3253
# 1    1196
# 3     967
# Name: cluster, dtype: int64

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=50)
clf=KNeighborsClassifier(n_neighbors=4)
clf.fit(X_train, y_train)
accuracy=clf.score(X_train, y_train)
print(accuracy)
# Out:
# 0.8748603351955307

# %%
X_test
# Out:
#           BALANCE  PURCHASES  ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  \
# 4597   922.615452      45.65             45.65                    0.00
# 1295    41.936627     717.92            122.86                  595.06
# 6167  1630.991993     578.90              0.00                  578.90
# 8529  5998.431562       0.00              0.00                    0.00
# 5112  1112.070216     179.24             59.00                  120.24
# ...           ...        ...               ...                     ...
# 4620   931.866057       0.00              0.00                    0.00
# 4035   668.742738     951.97            664.83                  287.14
# 613     14.179041     119.58              0.00                  119.58
# 2644   198.377577       0.00              0.00                    0.00
# 7322  2757.097566    1533.04            384.04                 1149.00
#
#       CASH_ADVANCE  CREDIT_LIMIT     PAYMENTS  Avg_cash_advance
# ...

# %%
example = np.array([[922.615452,45.65,45.65,0.00,0.000000,1700.0,191.287802,0.000000]])
prediction=clf.predict(example)
print(prediction)
# Out:
# [0]

# %%
import pickle

# %%
filename = 'Model_Mitali.pkl'
pickle.dump(clf, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
prediction=loaded_model.predict(example)
print(prediction)
# Out:
# [0]
