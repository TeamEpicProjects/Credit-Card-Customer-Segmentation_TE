# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("C:\\Users\\Mitali Patil\\Downloads\\data_credit_card_customer_seg.csv")
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10104      0.00000                0.0       0.00              0.00
# 1     C10187      0.00000                0.0      23.00              0.00
# 2     C10680      0.00000                0.0       0.00              0.00
# 3     C10891      0.00000                0.0     199.88              0.00
# 4     C11171      0.00000                0.0      12.65              0.00
# ...      ...          ...                ...        ...               ...
# 8945  C15429  16115.59640                1.0     684.74            105.30
# 8946  C16812  16259.44857                1.0    5024.68           3582.45
# 8947  C15642  16304.88925                1.0    1770.57              0.00
# 8948  C14256  18495.55855                1.0    5288.28           3657.30
# 8949  C10144  19043.13856                1.0   22009.92           9449.07
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df['CREDIT_LIMIT'].value_counts().head()
# Out:
# 3000.0    784
# 1500.0    722
# 1200.0    621
# 1000.0    614
# 2500.0    612
# Name: CREDIT_LIMIT, dtype: int64

# %%
df.round(2)
# Out:
#      CUST_ID   BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10104      0.00                0.0       0.00              0.00
# 1     C10187      0.00                0.0      23.00              0.00
# 2     C10680      0.00                0.0       0.00              0.00
# 3     C10891      0.00                0.0     199.88              0.00
# 4     C11171      0.00                0.0      12.65              0.00
# ...      ...       ...                ...        ...               ...
# 8945  C15429  16115.60                1.0     684.74            105.30
# 8946  C16812  16259.45                1.0    5024.68           3582.45
# 8947  C15642  16304.89                1.0    1770.57              0.00
# 8948  C14256  18495.56                1.0    5288.28           3657.30
# 8949  C10144  19043.14                1.0   22009.92           9449.07
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
print("MEAN: "+str(round(df['CREDIT_LIMIT'].mean(),2)))
df['CREDIT_LIMIT']=df['CREDIT_LIMIT'].fillna(round(df['CREDIT_LIMIT'].mean(),2))
# Out:
# MEAN: 4494.45

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          0
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
print("MEAN: "+str(round(df['MINIMUM_PAYMENTS'].mean(),2)))
df['MINIMUM_PAYMENTS']=df['MINIMUM_PAYMENTS'].fillna(round(df['MINIMUM_PAYMENTS'].mean(),2))
# Out:
# MEAN: 864.21

# %%
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df.shape
# Out:
# (8950, 18)

# %%
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10104      0.00000                0.0       0.00              0.00
# 1     C10187      0.00000                0.0      23.00              0.00
# 2     C10680      0.00000                0.0       0.00              0.00
# 3     C10891      0.00000                0.0     199.88              0.00
# 4     C11171      0.00000                0.0      12.65              0.00
# ...      ...          ...                ...        ...               ...
# 8945  C15429  16115.59640                1.0     684.74            105.30
# 8946  C16812  16259.44857                1.0    5024.68           3582.45
# 8947  C15642  16304.88925                1.0    1770.57              0.00
# 8948  C14256  18495.55855                1.0    5288.28           3657.30
# 8949  C10144  19043.13856                1.0   22009.92           9449.07
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
del df['CUST_ID']

# %%
df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0         0.00000                0.0       0.00              0.00
# 1         0.00000                0.0      23.00              0.00
# 2         0.00000                0.0       0.00              0.00
# 3         0.00000                0.0     199.88              0.00
# 4         0.00000                0.0      12.65              0.00
# ...           ...                ...        ...               ...
# 8945  16115.59640                1.0     684.74            105.30
# 8946  16259.44857                1.0    5024.68           3582.45
# 8947  16304.88925                1.0    1770.57              0.00
# 8948  18495.55855                1.0    5288.28           3657.30
# 8949  19043.13856                1.0   22009.92           9449.07
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                       0.00     89.849004             0.000000
# ...

# %%
df.nunique()
# Out:
# BALANCE                             8871
# BALANCE_FREQUENCY                     43
# PURCHASES                           6203
# ONEOFF_PURCHASES                    4014
# INSTALLMENTS_PURCHASES              4452
# CASH_ADVANCE                        4323
# PURCHASES_FREQUENCY                   47
# ONEOFF_PURCHASES_FREQUENCY            47
# PURCHASES_INSTALLMENTS_FREQUENCY      47
# CASH_ADVANCE_FREQUENCY                54
# CASH_ADVANCE_TRX                      65
# PURCHASES_TRX                        173
# CREDIT_LIMIT                         206
# PAYMENTS                            8711
# MINIMUM_PAYMENTS                    8637
# PRC_FULL_PAYMENT                      47
# TENURE                                 7
# dtype: int64

# %%
fig, ax=plt.subplots(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Purchases and OneOff_purchase have positve correlation of  0.92
# PURCHASES_FREQUENCY and PURCHASES_INSTALLMENT_FREQUENCY  0.86
# CASH_ADVANCE_TRX and CASH_ADVANCE_FREQUENCY  has positive correlatuion of 0.8

# %%
# Plot histograms to show distributions of each column
plt.figure(figsize=(10,50))
for i in range(len(df.columns)):
  plt.subplot(17, 1, i+1)
  sns.histplot(data=df[df.columns[i]], kde=True)
  plt.title(df.columns[i])

plt.tight_layout()

# %% [markdown]
# Balance = many user are left with balance upto 2500
# user are having tenure of <=12year
# maximum credit limit

# %%
sns.pairplot(df)
